# %% [markdown]
# This notebook is based on the github gensim tutorial:
# https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/Corpora_and_Vector_Spaces.ipynb
#
# # Training model using CDC as corpus
#
# Following the tutorial from github gensim, we will try to train a model to correlate a sentence to a document, in this case, we are going to test this approach using the "Codigo de Defesa do Consumidor".

# %% [markdown]
# To remember:
# - Gensim is a tool for discovering the semantic structure of documents by examining the taken corpus, a collection of text documents, and producing a vector representation of the text in the corpus.
# - Vector representation is used then to train a model, which is an algorithms to create different representations of the data, which are usually more semantic.

# %% [markdown]
# ## Corpus

# %%
# each chapter = each documents. Just for tests, we gonna try two documents and increase the reading / 
# trainning as soon more document are translated and prepared.

#textIOWrapper44 = open('../../Documents/cdc_en/chapter_4_4', 'r')
#chapterText44 = textIOWrapper44.read()
#chapterText44

#textIOWrapper43 = open('../../Documents/cdc_en/chapter_4_3', 'r')
#chapterText43 = textIOWrapper43.read()
#chapterText43

import os, codecs
directory = "../../Documents/cdc_en"
corpus = []

# print(os.listdir(directory))
for filename in os.listdir(directory):
    
    #for ascii files, use this line below:
    #fileOpenned = open(directory+os.sep+filename, 'r')
    
    #non-ascii files
    fileOpenned = codecs.open(directory+os.sep+filename, 'r', 'utf-8')
    
    textRead = fileOpenned.read()
    corpus.append(textRead)
    
    #print(textRead)
    #if filename.endswith(".asm") or ...
#print(corpus)

# %%
# STOPWORDS!
#set of frequent non-important words for this experiment
stopWordlist = set('well good bad can could may might would this those less more same her his our mine my from until only them was were will am among instead otherwise above under what when where do does have had has who that which whom shall , they other are under their it into by for a an of the and to in art. -   or paragraph its section is be than may as if there any with not one two three four five your on'.split())
#numerals = [i for i in range(1, 11)]

numerals = ''
for i in range(1, 11):
    numerals+=' '+str(i)
stopWordlist.update(numerals.split())

particularSWDocumentRelated = '§ chapter (vetoed). i ii iii iv v vi vii viii ix x'
stopWordlist.update(particularSWDocumentRelated.split())

print(stopWordlist)

#corpus = [chapterText43, chapterText44]
text = []
texts = []
for document in corpus:
    for word in document.lower().split():
        if word not in stopWordlist:
            text.append(word)
    texts.append(text)
    text = []
#texts
# Out:
# {'with', ',', 'those', 'had', 'would', 'not', 'one', 'is', 'any', 'his', 'do', 'does', 'under', 'chapter', 'for', 'shall', 'instead', 'might', 'bad', 'than', 'vi', 'x', 'paragraph', '§', 'iii', 'they', 'other', 'may', 'them', '5', 'and', 'art.', 'as', 'have', 'from', 'will', 'your', 'who', 'otherwise', 'their', 'our', '7', 'only', 'an', 'has', 'her', 'until', 'by', 'there', '3', '8', 'or', 'iv', 'am', 'of', 'four', 'good', 'that', 'was', 'viii', '(vetoed).', 'on', 'where', '1', 'into', 'be', 'i', 'its', 'this', 'if', 'three', 'above', '-', 'same', 'less', 'well', 'can', '9', 'which', 'when', '2', 'more', 'what', 'it', 'the', 'vii', 'ii', 'to', 'a', 'v', '6', 'whom', 'among', 'five', '4', 'ix', '10', 'mine', 'two', 'could', 'section', 'my', 'in', 'were', 'are'}

# %%
# MORE FREQUENT WORDS (>1) BY DOCUMENT / CHAPTER
#remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)

for text in texts:
    for token in text:
        frequency[token] +=1
    
processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]

from pprint import pprint #pretty-printer
pprint(processed_corpus)
# Out:
# [['quality',
#   'products',
#   'services,',
#   'prevention',
#   'reparation',
#   'damages',
#   'protection',
#   'health',
#   'article',
#   'products',
#   'services',
#   'placed',
#   'consumer',
#   'market',
#   'risks',
#   'health',
#   'safety',
#   'consumers,',
#   'except',
#   'considered',
#   'result',
#   'suppliers',
#   'circumstances,',
#   'information',
#   'about',
#   'single',
#   'paragraph.',
#   'case',
#   'industrial',
#   'product,',
#   'must',
#   'provide',
#   'information',
#   'referred',
#   'article,',
#   'through',
#   'appropriate',
#   'must',
#   'product.',
#   'supplier',
#   'products',
#   'services',
#   'harmful',
#   'dangerous',
#   'health',
#   'safety',
#   'must',
#   'adequate',
#   'about',
#   'harmfulness',
#   'without',
#   'prejudice',
#   'adoption',
#   'article',
#   'supplier',
#   'place',
#   'consumer',
#   'market',
#   'product',
#   'service',
#   'harmfulness',
#   'health',
#   '1.',
#   'supplier',
#   'products',
#   'services',
#   'that,',
#   'after',
#   'consumer',
#   'market,',
#   'aware',
#   'dangerousness',
#   'must',
#   'inform',
#   'competent',
#   'consumers',
#   'means',
#   '2.',
#   'referred',
#   'previous',
#   'at',
#   'expense',
#   'supplier',
#   'product',
#   '3.',
#   'whenever',
#   'aware',
#   'dangerousness',
#   'products',
#   'services',
#   'health',
#   'safety',
#   'consumers,',
#   'federal',
#   'inform'],
#  ['quality',
#   'products',
#   'services,',
#   'prevention',
#   'reparation',
#   'damages',
#   'responsibility',
#   'product',
#   'fact',
#   'service',
#   'article',
#   'manufacturer,',
#   'producer,',
#   'manufacturer,',
#   'national',
#   'foreign,',
#   'importer',
#   'regardless',
#   'existence',
#   'fault,',
#   'repair',
#   'damages',
#   'caused',
#   'consumers',
#   'defects',
#   'manufacture,',
#   'construction,',
#   'assembly,',
#   'products,',
#   'insufficient',
#   'inadequate',
#   'information',
#   'use',
#   'risks.',
#   'product',
#   'defective',
#   'offer',
#   'security',
#   'expected',
#   'taking',
#   'account',
#   'relevant',
#   'circumstances,',
#   'which:',
#   'presentation;',
#   'use',
#   'risks',
#   'reasonably',
#   'expected',
#   'time',
#   'product',
#   'considered',
#   'defective',
#   'another',
#   'quality',
#   'been',
#   'placed',
#   'market.',
#   '3.',
#   'manufacturer,',
#   'manufacturer,',
#   'producer',
#   'importer',
#   'liable',
#   'place',
#   'product',
#   'market;',
#   'although',
#   'product',
#   'been',
#   'placed',
#   'market,',
#   'defect',
#   'exist;',
#   'exclusive',
#   'fault',
#   'consumer',
#   'third',
#   'party.',
#   'article',
#   'also',
#   'responsible,',
#   'terms',
#   'previous',
#   'article,',
#   'manufacturer,',
#   'manufacturer,',
#   'producer',
#   'importer',
#   'product',
#   'without',
#   'clear',
#   'manufacturer,',
#   'producer,',
#   'builder',
#   'products',
#   'single',
#   'paragraph.',
#   'right',
#   'return',
#   'against',
#   'others',
#   'responsible,',
#   'according',
#   'causing',
#   'harmful',
#   'article',
#   'service',
#   'provider',
#   'regardless',
#   'existence',
#   'fault,',
#   'repair',
#   'damages',
#   'caused',
#   'consumers',
#   'defects',
#   'provision',
#   'services,',
#   'insufficient',
#   'inadequate',
#   'information',
#   'risks.',
#   'service',
#   'defective',
#   'provide',
#   'security',
#   'consumer',
#   'taking',
#   'account',
#   'relevant',
#   'circumstances,',
#   'which:',
#   'result',
#   'risks',
#   'reasonably',
#   'expected',
#   'time',
#   '2.',
#   'service',
#   'considered',
#   'defective',
#   'adoption',
#   'new',
#   'service',
#   'provider',
#   'liable',
#   'that,',
#   'service,',
#   'defect',
#   'exist;',
#   'exclusive',
#   'fault',
#   'consumer',
#   'third',
#   'party.',
#   'responsibility',
#   'through',
#   'fault.',
#   'all',
#   'victims',
#   'consumers.'],
#  ['quality',
#   'products',
#   'services,',
#   'prevention',
#   'reparation',
#   'damages',
#   'disregard',
#   'legal',
#   'personality',
#   'article',
#   'disregard',
#   'legal',
#   'personality',
#   'when,',
#   'consumer,',
#   'law,',
#   'law,',
#   'fact',
#   'social',
#   'disregard',
#   'also',
#   'effective',
#   'legal',
#   'caused',
#   '2.',
#   'companies',
#   'part',
#   'responsible',
#   'obligations',
#   'arising',
#   'code.',
#   'companies',
#   'jointly',
#   'severally',
#   'liable',
#   'obligations',
#   'arising',
#   'code.',
#   'companies',
#   'fault.',
#   'legal',
#   'person',
#   'also',
#   'whenever',
#   'personality',
#   'damages',
#   'caused',
#   'consumers.'],
#  ['quality',
#   'products',
#   'services,',
#   'prevention',
#   'reparation',
#   'damages',
#   'responsibility',
#   'product',
#   'service',
#   'article',
#   'suppliers',
#   'durable',
#   'non-durable',
#   'consumer',
#   'products',
#   'jointly',
#   'severally',
#   'liable',
#   'defects',
#   'quality',
#   'quantity',
#   'unfit',
#   'inadequate',
#   'consumption',
#   'reduction',
#   'value,',
#   'resulting',
#   'indications',
#   'container,',
#   'packaging,',
#   'labeling',
#   'advertising',
#   'message,',
#   'due',
#   'nature,',
#   'consumer',
#   'replacement',
#   '1.',
#   'defect',
#   'within',
#   'period',
#   'days,',
#   'consumer',
#   'may,',
#   'alternatively',
#   'at',
#   'replacement',
#   'product',
#   'another',
#   'species,',
#   'immediate',
#   'return',
#   'amount',
#   'paid,',
#   'monetarily',
#   'updated,',
#   'without',
#   'prejudice',
#   'losses',
#   'damages;',
#   'proportional',
#   'reduction',
#   'price.',
#   '2.',
#   'reduce',
#   'period',
#   'provided',
#   'term',
#   'clause',
#   'must',
#   'means',
#   'consumer.',
#   '3.',
#   'consumer',
#   'make',
#   'immediate',
#   'use',
#   'article',
#   'due',
#   'substitution',
#   'defective',
#   'quality',
#   'product,',
#   'reduce',
#   'product.',
#   '4.',
#   'consumer',
#   'alternative',
#   'item',
#   'article,',
#   'good,',
#   'substitution',
#   'another',
#   'different',
#   'brand',
#   'model,',
#   'without',
#   'prejudice',
#   'provisions',
#   'article.',
#   'case',
#   'supply',
#   'products,',
#   'immediate',
#   'supplier',
#   'liable',
#   'consumer,',
#   'except',
#   'clearly',
#   'unfit',
#   'use',
#   'products',
#   'products',
#   'harmful',
#   'dangerous',
#   'regulations',
#   'manufacture,',
#   'distribution',
#   'presentation;',
#   'products',
#   'prove',
#   'purpose',
#   'article',
#   'suppliers',
#   'jointly',
#   'severally',
#   'liable',
#   'defects',
#   'quantity',
#   'product',
#   'changes',
#   'nature,',
#   'information',
#   'container,',
#   'packaging,',
#   'labeling',
#   'advertising',
#   'message,',
#   'alternatively',
#   'at',
#   'choice:',
#   'proportional',
#   'reduction',
#   'replacement',
#   'product',
#   'another',
#   'species,',
#   'brand',
#   'model,',
#   'without',
#   'immediate',
#   'return',
#   'amount',
#   'paid,',
#   'monetarily',
#   'updated,',
#   'without',
#   'prejudice',
#   'losses',
#   '1.',
#   'provisions',
#   'previous',
#   'article',
#   'article.',
#   '2.',
#   'immediate',
#   'supplier',
#   'responsible',
#   'according',
#   'service',
#   'provider',
#   'quality',
#   'defects',
#   'make',
#   'unfit',
#   'consumption',
#   'value,',
#   'resulting',
#   'indications',
#   'offer',
#   'advertising',
#   'message,',
#   'consumer',
#   'may,',
#   'choice:',
#   'services,',
#   'without',
#   'immediate',
#   'return',
#   'amount',
#   'paid,',
#   'monetarily',
#   'updated,',
#   'without',
#   'prejudice',
#   'losses',
#   'damages;',
#   'proportional',
#   'reduction',
#   'price.',
#   '1.',
#   'services',
#   'third',
#   'at',
#   'expense',
#   '2.',
#   'services',
#   'prove',
#   'inadequate',
#   'reasonably',
#   'expected',
#   'comply',
#   'article',
#   'provision',
#   'services',
#   'purpose',
#   'product,',
#   'obligation',
#   'supplier',
#   'use',
#   'appropriate',
#   'new',
#   'replacement',
#   'technical',
#   'except',
#   'consumer.',
#   'article',
#   'public',
#   'provide',
#   'services.',
#   'single',
#   'paragraph.',
#   'obligations',
#   'referred',
#   'article,',
#   'legal',
#   'comply',
#   'repair',
#   'damages',
#   'provided',
#   'code.',
#   'supplier',
#   'about',
#   'quality',
#   'defects',
#   'due',
#   'products',
#   'services',
#   'legal',
#   'product',
#   'service',
#   'contractual',
#   'prohibited.',
#   'article',
#   'contractual',
#   'provision',
#   'clause',
#   'obligation',
#   'provided',
#   'previous',
#   'prohibited.',
#   '1.',
#   'responsible',
#   'causing',
#   'all',
#   'jointly',
#   'liable',
#   'reparation',
#   'provided',
#   'previous',
#   '2.',
#   'damage',
#   'caused',
#   'part',
#   'product',
#   'service,',
#   'jointly',
#   'responsible',
#   'manufacturer,',
#   'builder',
#   'importer',
#   'out'],
#  ['general',
#   'provisions',
#   'code',
#   'standards',
#   'protection',
#   'defense',
#   'consumer,',
#   'public',
#   'order',
#   'social',
#   'terms',
#   'item',
#   'item',
#   'federal',
#   '2.',
#   'consumer',
#   'natural',
#   'legal',
#   'person',
#   'product',
#   'service',
#   'single',
#   'paragraph.',
#   'consumer',
#   'collective',
#   'although',
#   'consumer',
#   'relations.',
#   'supplier',
#   'natural',
#   'legal',
#   'person,',
#   'public',
#   'national',
#   'foreign,',
#   'out',
#   'assembly,',
#   'construction,',
#   'distribution',
#   'products',
#   'services.',
#   'provision',
#   'services.',
#   'product',
#   'good,',
#   'service',
#   'provided',
#   'consumer',
#   'market,',
#   'including',
#   'security',
#   'nature,',
#   'except',
#   'arising',
#   'relations.'],
#  ['basic',
#   'consumer',
#   'rights',
#   'basic',
#   'consumer',
#   'rights',
#   'protection',
#   'life,',
#   'health',
#   'safety',
#   'against',
#   'risks',
#   'caused',
#   'practices',
#   'supply',
#   'products',
#   'services',
#   'considered',
#   'dangerous',
#   'education',
#   'adequate',
#   'consumption',
#   'products',
#   'services,',
#   'ensuring',
#   'adequate',
#   'clear',
#   'information',
#   'different',
#   'products',
#   'services,',
#   'correct',
#   'specification',
#   'quantity,',
#   'characteristics,',
#   'composition,',
#   'quality',
#   'price,',
#   'risks',
#   'present;',
#   'adequate',
#   'clear',
#   'information',
#   'different',
#   'products',
#   'services,',
#   'correct',
#   'specification',
#   'quantity,',
#   'characteristics,',
#   'composition,',
#   'quality,',
#   'price,',
#   'risks',
#   'present;',
#   '(drafting',
#   'provided',
#   'law',
#   'no.',
#   'protection',
#   'against',
#   'abusive',
#   'unfair',
#   'practices',
#   'clauses',
#   'abusive',
#   'provision',
#   'services;',
#   'contractual',
#   'clauses',
#   'due',
#   'make',
#   'effective',
#   'prevention',
#   'moral',
#   'damages,',
#   'individual,',
#   'collective',
#   'administrative',
#   'view',
#   'individual,',
#   'collective',
#   'moral',
#   'damages,',
#   'ensuring',
#   'administrative',
#   'technical',
#   'protection',
#   'defense',
#   'including',
#   'civil',
#   'when,',
#   'at',
#   'according',
#   'ordinary',
#   'rules',
#   'adequate',
#   'effective',
#   'provision',
#   'public',
#   'services',
#   'single',
#   'paragraph.',
#   'information',
#   'referred',
#   'item',
#   'article',
#   'must',
#   'person,',
#   'provisions',
#   'law',
#   'no.',
#   'article',
#   'rights',
#   'provided',
#   'code',
#   'others',
#   'arising',
#   'ordinary',
#   'regulations',
#   'competent',
#   'administrative',
#   'general',
#   'principles',
#   'law,',
#   'single',
#   'paragraph.',
#   'all',
#   'jointly',
#   'severally',
#   'liable',
#   'damages',
#   'provided',
#   'rules'],
#  ['quality',
#   'products',
#   'services,',
#   'prevention',
#   'reparation',
#   'damages',
#   'right',
#   'about',
#   'defects',
#   'case',
#   'service',
#   'provision',
#   'non-durable',
#   'days,',
#   'case',
#   'service',
#   'provision',
#   'durable',
#   '1.',
#   'decadential',
#   'period',
#   'begins',
#   'after',
#   'effective',
#   'product',
#   'execution',
#   'services.',
#   '2.',
#   'consumer',
#   'supplier',
#   'products',
#   'services',
#   'must',
#   'clearly',
#   'civil',
#   '3.',
#   'case',
#   'decadential',
#   'term',
#   'begins',
#   'defect',
#   'reparation',
#   'damages',
#   'caused',
#   'fact',
#   'product',
#   'service',
#   'provided',
#   'term',
#   'damage',
#   'single',
#   'paragraph.'],
#  ['national',
#   'policy',
#   'consumer',
#   'relations',
#   'article',
#   '4.',
#   'national',
#   'policy',
#   'consumer',
#   'relations',
#   'consumers,',
#   'health',
#   'safety,',
#   'protection',
#   'economic',
#   'improvement',
#   'quality',
#   'life,',
#   'consumer',
#   'relations,',
#   'following',
#   'following',
#   '(drafting',
#   'provided',
#   'law',
#   'consumer',
#   'consumer',
#   'market;',
#   'incentives',
#   'creation',
#   'development',
#   'consumer',
#   'market;',
#   'products',
#   'services',
#   'adequate',
#   'standards',
#   'quality,',
#   'safety,',
#   'consumer',
#   'relations',
#   'consumer',
#   'protection',
#   'economic',
#   'order',
#   'make',
#   'principles',
#   'economic',
#   'order',
#   'based',
#   'federal',
#   'based',
#   'relations',
#   'consumers',
#   'education',
#   'information',
#   'suppliers',
#   'consumers,',
#   'rights',
#   'view',
#   'consumer',
#   'market;',
#   'creation',
#   'suppliers',
#   'efficient',
#   'means',
#   'quality',
#   'safety',
#   'products',
#   'services,',
#   'alternative',
#   'solution',
#   'efficient',
#   'all',
#   'consumer',
#   'market,',
#   'including',
#   'unfair',
#   'industrial',
#   'improvement',
#   'public',
#   'services;',
#   'changes',
#   'consumer',
#   'market.',
#   'article',
#   'execution',
#   'national',
#   'policy',
#   'consumer',
#   'relations,',
#   'public',
#   'following',
#   'legal',
#   'public',
#   'consumer',
#   'within',
#   'public',
#   'creation',
#   'specialized',
#   'consumers',
#   'victims',
#   'creation',
#   'specialized',
#   'solution',
#   'consumer',
#   'incentives',
#   'creation',
#   'development',
#   'consumer',
#   'protection']]

# %%
# Associanting each word with a unique id, i.e., creating a dictionary
from gensim import corpora

dictionary = corpora.Dictionary(processed_corpus)
print(dictionary)
# Out:
# Dictionary(266 unique tokens: ['quality', 'products', 'services,', 'prevention', 'reparation']...)

# %% [markdown]
# ## Vectorization
#
# To infer the latent structure in our corpus we need a way to represent documents that we can manipulate mathematically. One approach is to represent each document as a vector. There are various approaches for creating a vector representation of a document but a simple example is the bag-of-words model. Under the bag-of-words model each document is represented by a vector containing the frequency counts of each word in the dictionary. For example, given a dictionary containing the words ['coffee', 'milk', 'sugar', 'spoon'] a document consisting of the string "coffee milk coffee" could be represented by the vector [2, 1, 0, 0] where the entries of the vector are (in order) the occurrences of "coffee", "milk", "sugar" and "spoon" in the document. The length of the vector is the number of entries in the dictionary.

# %%
print( dictionary.token2id)
# Out:
# {'quality': 0, 'products': 1, 'services,': 2, 'prevention': 3, 'reparation': 4, 'damages': 5, 'protection': 6, 'health': 7, 'article': 8, 'services': 9, 'placed': 10, 'consumer': 11, 'market': 12, 'risks': 13, 'safety': 14, 'consumers,': 15, 'except': 16, 'considered': 17, 'result': 18, 'suppliers': 19, 'circumstances,': 20, 'information': 21, 'about': 22, 'single': 23, 'paragraph.': 24, 'case': 25, 'industrial': 26, 'product,': 27, 'must': 28, 'provide': 29, 'referred': 30, 'article,': 31, 'through': 32, 'appropriate': 33, 'product.': 34, 'supplier': 35, 'harmful': 36, 'dangerous': 37, 'adequate': 38, 'harmfulness': 39, 'without': 40, 'prejudice': 41, 'adoption': 42, 'place': 43, 'product': 44, 'service': 45, '1.': 46, 'that,': 47, 'after': 48, 'market,': 49, 'aware': 50, 'dangerousness': 51, 'inform': 52, 'competent': 53, 'consumers': 54, 'means': 55, '2.': 56, 'previous': 57, 'at': 58, 'expense': 59, '3.': 60, 'whenever': 61, 'federal': 62, 'responsibility': 63, 'fact': 64, 'manufacturer,': 65, 'producer,': 66, 'national': 67, 'foreign,': 68, 'importer': 69, 'regardless': 70, 'existence': 71, 'fault,': 72, 'repair': 73, 'caused': 74, 'defects': 75, 'manufacture,': 76, 'construction,': 77, 'assembly,': 78, 'products,': 79, 'insufficient': 80, 'inadequate': 81, 'use': 82, 'risks.': 83, 'defective': 84, 'offer': 85, 'security': 86, 'expected': 87, 'taking': 88, 'account': 89, 'relevant': 90, 'which:': 91, 'presentation;': 92, 'reasonably': 93, 'time': 94, 'another': 95, 'been': 96, 'market.': 97, 'producer': 98, 'liable': 99, 'market;': 100, 'although': 101, 'defect': 102, 'exist;': 103, 'exclusive': 104, 'fault': 105, 'third': 106, 'party.': 107, 'also': 108, 'responsible,': 109, 'terms': 110, 'clear': 111, 'builder': 112, 'right': 113, 'return': 114, 'against': 115, 'others': 116, 'according': 117, 'causing': 118, 'provider': 119, 'provision': 120, 'new': 121, 'service,': 122, 'fault.': 123, 'all': 124, 'victims': 125, 'consumers.': 126, 'disregard': 127, 'legal': 128, 'personality': 129, 'when,': 130, 'consumer,': 131, 'law,': 132, 'social': 133, 'effective': 134, 'companies': 135, 'part': 136, 'responsible': 137, 'obligations': 138, 'arising': 139, 'code.': 140, 'jointly': 141, 'severally': 142, 'person': 143, 'durable': 144, 'non-durable': 145, 'quantity': 146, 'unfit': 147, 'consumption': 148, 'reduction': 149, 'value,': 150, 'resulting': 151, 'indications': 152, 'container,': 153, 'packaging,': 154, 'labeling': 155, 'advertising': 156, 'message,': 157, 'due': 158, 'nature,': 159, 'replacement': 160, 'within': 161, 'period': 162, 'days,': 163, 'may,': 164, 'alternatively': 165, 'species,': 166, 'immediate': 167, 'amount': 168, 'paid,': 169, 'monetarily': 170, 'updated,': 171, 'losses': 172, 'damages;': 173, 'proportional': 174, 'price.': 175, 'reduce': 176, 'provided': 177, 'term': 178, 'clause': 179, 'consumer.': 180, 'make': 181, 'substitution': 182, '4.': 183, 'alternative': 184, 'item': 185, 'good,': 186, 'different': 187, 'brand': 188, 'model,': 189, 'provisions': 190, 'article.': 191, 'supply': 192, 'clearly': 193, 'regulations': 194, 'distribution': 195, 'prove': 196, 'purpose': 197, 'changes': 198, 'choice:': 199, 'comply': 200, 'obligation': 201, 'technical': 202, 'public': 203, 'services.': 204, 'contractual': 205, 'prohibited.': 206, 'damage': 207, 'out': 208, 'general': 209, 'code': 210, 'standards': 211, 'defense': 212, 'order': 213, 'natural': 214, 'collective': 215, 'relations.': 216, 'person,': 217, 'including': 218, 'basic': 219, 'rights': 220, 'life,': 221, 'practices': 222, 'education': 223, 'ensuring': 224, 'correct': 225, 'specification': 226, 'quantity,': 227, 'characteristics,': 228, 'composition,': 229, 'price,': 230, 'present;': 231, 'quality,': 232, '(drafting': 233, 'law': 234, 'no.': 235, 'abusive': 236, 'unfair': 237, 'clauses': 238, 'services;': 239, 'moral': 240, 'damages,': 241, 'individual,': 242, 'administrative': 243, 'view': 244, 'civil': 245, 'ordinary': 246, 'rules': 247, 'principles ...

# %%
example_claim = "I made the purchase and payment for two products in \
the PurpleFire.com store on December 9th. And they have 15 days to do \
the posting. But there is no doing. And I've been waiting for more than\
1 month. I contacted the company several times and talked to Amanda\
(amandapt1313@gmail.com), but they did not solve my problem. I have all\
the conversations filed. And I want to point out here that the \
PurpleFire store has no CNPJ and no address on the site. I would not recommend\
anyone to make any purchase with the store mentioned."

vec_claim = dictionary.doc2bow(example_claim.lower().split())
vec_claim
# Out:
# [(1, 1), (96, 1), (181, 1), (208, 1)]

# %%
#vectoring the dictionary / corpus
bow_corpus = [dictionary.doc2bow(text) for text in processed_corpus]
print(bow_corpus)
# Out:
# [[(0, 1), (1, 5), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 5), (8, 2), (9, 4), (10, 1), (11, 3), (12, 2), (13, 1), (14, 3), (15, 2), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 2), (22, 2), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 4), (29, 1), (30, 2), (31, 1), (32, 1), (33, 1), (34, 1), (35, 4), (36, 1), (37, 1), (38, 1), (39, 2), (40, 1), (41, 1), (42, 1), (43, 1), (44, 2), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 2), (51, 2), (52, 2), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1)], [(0, 2), (1, 2), (2, 2), (3, 1), (4, 1), (5, 3), (8, 3), (10, 2), (11, 3), (13, 2), (17, 2), (18, 1), (20, 2), (21, 2), (23, 1), (24, 1), (29, 1), (31, 1), (32, 1), (36, 1), (40, 1), (42, 1), (43, 1), (44, 6), (45, 5), (47, 1), (49, 1), (54, 2), (56, 1), (57, 1), (60, 1), (63, 2), (64, 1), (65, 7), (66, 2), (67, 1), (68, 1), (69, 3), (70, 2), (71, 2), (72, 2), (73, 2), (74, 2), (75, 2), (76, 1), (77, 1), (78, 1), (79, 1), (80, 2), (81, 2), (82, 2), (83, 2), (84, 4), (85, 1), (86, 2), (87, 3), (88, 2), (89, 2), (90, 2), (91, 2), (92, 1), (93, 2), (94, 2), (95, 1), (96, 2), (97, 1), (98, 2), (99, 2), (100, 1), (101, 1), (102, 2), (103, 2), (104, 2), (105, 2), (106, 2), (107, 2), (108, 1), (109, 2), (110, 1), (111, 1), (112, 1), (113, 1), (114, 1), (115, 1), (116, 1), (117, 1), (118, 1), (119, 2), (120, 1), (121, 1), (122, 1), (123, 1), (124, 1), (125, 1), (126, 1)], [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2), (8, 1), (56, 1), (61, 1), (64, 1), (74, 2), (99, 1), (108, 2), (123, 1), (126, 1), (127, 3), (128, 4), (129, 3), (130, 1), (131, 1), (132, 2), (133, 1), (134, 1), (135, 3), (136, 1), (137, 1), (138, 2), (139, 2), (140, 2), (141, 1), (142, 1), (143, 1)], [(0, 5), (1, 6), (2, 2), (3, 1), (4, 2), (5, 2), (8, 7), (9, 4), (11, 6), (16, 2), (19, 2), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (27, 2), (28, 1), (29, 1), (30, 1), (31, 2), (33, 1), (34, 1), (35, 4), (36, 1), (37, 1), (40, 6), (41, 4), (44, 6), (45, 3), (46, 4), (55, 1), (56, 4), (57, 3), (58, 3), (59, 1), (60, 1), (63, 1), (65, 1), (69, 1), (73, 1), (74, 1), (75, 4), (76, 1), (79, 1), (81, 2), (82, 3), (84, 1), (85, 1), (87, 1), (92, 1), (93, 1), (95, 3), (99, 4), (102, 1), (106, 1), (112, 1), (114, 3), (117, 1), (118, 1), (119, 1), (120, 2), (121, 1), (122, 1), (124, 1), (128, 2), (131, 1), (136, 1), (137, 3), (138, 1), (140, 1), (141, 4), (142, 2), (144, 1), (145, 1), (146, 2), (147, 3), (148, 2), (149, 4), (150, 2), (151, 2), (152, 2), (153, 2), (154, 2), (155, 2), (156, 3), (157, 3), (158, 3), (159, 2), (160, 4), (161, 1), (162, 2), (163, 1), (164, 2), (165, 2), (166, 2), (167, 6), (168, 3), (169, 3), (170, 3), (171, 3), (172, 3), (173, 2), (174, 3), (175, 2), (176, 2), (177, 4), (178, 1), (179, 2), (180, 2), (181, 2), (182, 2), (183, 1), (184, 1), (185, 1), (186, 1), (187, 1), (188, 2), (189, 2), (190, 2), (191, 2), (192, 1), (193, 1), (194, 1), (195, 1), (196, 2), (197, 2), (198, 1), (199, 2), (200, 2), (201, 2), (202, 1), (203, 1), (204, 1), (205, 2), (206, 2), (207, 1), (208, 1)], [(1, 1), (6, 1), (11, 4), (16, 1), (23, 1), (24, 1), (35, 1), (44, 2), (45, 2), (49, 1), (56, 1), (62, 1), (67, 1), (68, 1), (77, 1), (78, 1), (86, 1), (101, 1), (110, 1), (120, 1), (128, 2), (131, 1), (133, 1), (139, 1), (143, 1), (159, 1), (177, 1), (185, 2), (186, 1), (190, 1), (195, 1), (203, 2), (204, 2), (208, 1), (209, 1), (210, 1), (211, 1), (212, 1), (213, 1), (214, 2), (215, 1), (216, 2), (217, 1), (218, 1)], [(0, 1), (1, 4), (2, 3), (3, 1), (5, 1), (6, 3), (7, 1), (8, 2), (9, 2), (11, 2), (13, 3), (14, 1), (17, 1), (21, 3), (23, 2), (24, 2), (28, 1), (30, 1), (37, 1), (38, 4), (53, 1), (58, 1), (74, 1), (99, 1), (111, 2), (115, 2), (116, 1), (117, 1), (120, 2), (124, 1), (130, 1), (132, 1), (134, 2), (139, 1), (141, 1), (142, 1), (148, 1), (158, 1), (177, 3), (181, 1), (185, 1), (187, 2), (190, 1), (192, 1), (194, 1), (202, 1), (203, 1), (205, 1), (209, 1), (210, 1), (212, 1), (215, 2), (217, 1), (218, 1), (219, 2), ...

# %% [markdown]
# ## Model
#
# Now that we have vectorized our corpus we can begin to transform it using models. We use model as an abstract term referring to a transformation from one document representation to another. In gensim documents are represented as vectors so a model can be thought of as a transformation between two vector spaces. The details of this transformation are learned from the training corpus.
# One simple example of a model is tf-idf. The tf-idf model transforms vectors from the bag-of-words representation to a vector space where the frequency counts are weighted according to the relative rarity of each word in the corpus.

# %%
from gensim import models
# train the model
tfidf = models.TfidfModel(bow_corpus)
# transform the string
tfidf[dictionary.doc2bow("i would like to have my money back based on the product that i bought in 25 days back then. It suffered some decadential loss but still not satisfied with my product.".lower().split())]
# Out:
# [(34, 0.4220143629672883),
#  (44, 0.1430780415410627),
#  (249, 0.6330215444509324),
#  (262, 0.6330215444509324)]
